numpy.array([12.5,37.5,62.5,87.5,112.5,137.5,162.5,187.5,212.5,237.5,262.5,287.5,312.5,337.5,362.5,387.5,412.5,437.5,462.5,487.5,512.5,537.5,562.5,587.5,612.5,637.5,662.5,687.5,712.5,737.5,762.5,787.5,812.5,837.5,862.5,887.5,912.5,937.5,962.5,987.5])
# Creating weights for histo: y1_MET_0
y1_MET_0_weightsD = numpy.array([0.0106548856789,0.0330041650036,0.0504157918837,0.0618503198409,0.0766631994096,0.0847193395855,0.0896569721367,0.0844594594289,0.0769230795663,0.0743243322548,0.0592515544446,0.0504157918837,0.0415800474078,0.0371621570849,0.0283263945241,0.0207900146615,0.01455301388,0.0142931391489,0.00805613294193,0.00831600767307,0.00857588421271,0.00779625821078,0.00467775420307,0.00597713147578,0.00571725493615,0.00441787947193,0.00311850400771,0.00519750547385,0.00389812820115,0.00233887800578,0.00311850400771,0.00259875273693,0.000779625821078,0.00259875273693,0.001819126735,0.00103950109477,0.00103950109477,0.00129937636846,0.000519750547385,0.000519750547385])


 # Creating data sequence: middle of each bin
xDataE = numpy.array([12.5,37.5,62.5,87.5,112.5,137.5,162.5,187.5,212.5,237.5,262.5,287.5,312.5,337.5,362.5,387.5,412.5,437.5,462.5,487.5,512.5,537.5,562.5,587.5,612.5,637.5,662.5,687.5,712.5,737.5,762.5,787.5,812.5,837.5,862.5,887.5,912.5,937.5,962.5,987.5])
# Creating weights for histo: y1_MET_0
y1_MET_0_weightsE = numpy.array([0.0113965614551,0.0314854184812,0.0527332343674,0.0587212737852,0.0728221050167,0.0905930073453,0.0892408656455,0.082673373071,0.074367404256,0.0730152625562,0.0573691320853,0.0513811121293,0.0426888087736,0.0343828399586,0.0283948200026,0.0227931151255,0.0193162074064,0.0113965614551,0.0108170752134,0.00946494129831,0.0102375889718,0.00676067152186,0.00791964400517,0.00347691744993,0.00482905136507,0.00405640369158,0.00482905136507,0.00193162074064,0.00289743120827,0.00193162074064,0.00347691744993,0.00173845853035,0.00193162074064,0.00173845853035,0.00173845853035,0.00115897248331,0.000772648257334,0.00115897248331,0.000579486241655,0.00115897248331])



fig   = plt.figure(figsize=(8,6),dpi=80)


plt.hist(x=xDataA, bins=xBinning, weights=y1_MET_0_weightsA,\
             histtype="step", rwidth=1.0,\
             color=None, edgecolor="black", linewidth=1, linestyle="solid",\
             bottom=None, cumulative=False, normed=False, align="mid", orientation="vertical",
             label='No Matching (0 partons)')

# plt.hist(x=xData, bins=xBinning, weights=y1_MET_0_weights,\
#              histtype="step", rwidth=1.0,\
#              color=None, edgecolor="#5954d8", linewidth=1, linestyle="solid",\
#              bottom=None, cumulative=False, normed=False, align="mid", orientation="vertical",
#             label='CKKW 30 (with susy cut)')

plt.hist(x=xDataB, bins=xBinning, weights=y1_MET_0_weightsB,\
              histtype="step", rwidth=1.0,\
             color=None, edgecolor="red", linewidth=1, linestyle="solid",\
             bottom=None, cumulative=False, normed=False, align="mid", orientation="vertical",
            label='CKKW 30 (no susy cut)')

plt.hist(x=xDataC, bins=xBinning, weights=y1_MET_0_weightsC,\
             histtype="step", rwidth=1.0,\
             color=None, edgecolor="orange", linewidth=1, linestyle="solid",\
             bottom=None, cumulative=False, normed=False, align="mid", orientation="vertical",
             label='CKKW 60 (no susy cut)')


plt.hist(x=xDataD, bins=xBinning, weights=y1_MET_0_weightsD,\
             histtype="step", rwidth=1.0,\
             color=None, edgecolor="black", linewidth=1, linestyle="--",\
             bottom=None, cumulative=False, normed=False, align="mid", orientation="vertical",
             label='MLM 30')

plt.hist(x=xDataE, bins=xBinning, weights=y1_MET_0_weightsE,\
             histtype="step", rwidth=1.0,\
             color=None, edgecolor="green", linewidth=1, linestyle="--",\
             bottom=None, cumulative=False, normed=False, align="mid", orientation="vertical",
             label='MLM 60')


    # Axis
plt.rc('text',usetex=False)
plt.xlabel(r"$\slash{E}_{T}$ $(GeV)$ ",\
               fontsize=16,color="black")
plt.ylabel(r"$\mathrm{Events}$ $(\mathrm{scaled}\ \mathrm{to}\ \mathrm{one})$",\
               fontsize=16,color="black")

plt.gca().set_ylim(0.02,0.1)
plt.gca().set_xlim(0.0,400.)
plt.legend()
# plt.yscale('log')
plt.show()

# %%
METcut = 0.
METCKK30cut = 0.
METCKK60cut = 0.
for i,x in enumerate(xDataD):
    if x > 200.:
        METcut += y1_MET_0_weightsA[i]
        METCKK30cut += y1_MET_0_weightsB[i]
        METCKK60cut += y1_MET_0_weightsC[i]
print(METcut,METCKK30cut,METCKK60cut)
# Out:
# 0.48969998230827694 0.46669620481465995 0.5485905042707201

# %%
xDataA = numpy.array([12.5,37.5,62.5,87.5,112.5,137.5,162.5,187.5,212.5,237.5,262.5,287.5,312.5,337.5,362.5,387.5,412.5,437.5,462.5,487.5,512.5,537.5,562.5,587.5,612.5,637.5,662.5,687.5,712.5,737.5,762.5,787.5,812.5,837.5,862.5,887.5,912.5,937.5,962.5,987.5])
# Creating weights for histo: y1_MET_0
y1_MET_0_weightsA = numpy.array([0.0121999991895,0.0364000095895,0.0538000024637,0.071099995141,0.079200011088,0.0881000079188,0.0833999986656,0.0803999927593,0.0794999909875,0.0707999945504,0.0609999959476,0.0484999920293,0.0426000011047,0.0333000034864,0.0218000015367,0.020799999568,0.0174000011506,0.0117000002743,0.0120000008649,0.00899999909683,0.00829999978781,0.00729999988816,0.00640000018539,0.00460000077985,0.00450000058297,0.00389999940172,0.00399999959859,0.00389999940172,0.00120000008649,0.00260000098055,0.00180000002628,0.00250000078368,0.00130000007645,0.00209999999617,0.00120000008649,0.00180000002628,0.00120000008649,0.000699999929754,0.000899999909683,0.00110000009652])


# Creating data sequence: middle of each bin
xData = numpy.array([12.5,37.5,62.5,87.5,112.5,137.5,162.5,187.5,212.5,237.5,262.5,287.5,312.5,337.5,362.5,387.5,412.5,437.5,462.5,487.5,512.5,537.5,562.5,587.5,612.5,637.5,662.5,687.5,712.5,737.5,762.5,787.5,812.5,837.5,862.5,887.5,912.5,937.5,962.5,987.5])
# Creating weights for histo: y1_MET_0
y1_MET_0_weights = numpy.array([0.0140037116657,0.0425172932501,0.0666441699753,0.0882402554356,0.102412686519,0.100050614672,0.100050614672,0.0966762263186,0.0895900107769,0.0713683136697,0.0678252058989,0.0507845447153,0.0345874806201,0.0253079126488,0.0146785910235,0.0138349939352,0.00506158421696,0.00371182887569,0.00303694951786,0.00151847526509,0.00134975584743,0.00101231701211,0.00168719417659,0.000674878008075,0.000674878008075,0.000674877839355,1.73234517995e-10,0.000337439004037,0.000168719755098,0.000337439004037,8.52648210174e-11,0.000168719417659,1.3213070541e-10,1.20489217439e-10,0.000337439004037,0.000337439004037,1.02973965406e-10,4.86700517416e-11,0.000168719586378,7.46008933524e-11])

xDataB = numpy.array([12.5,37.5,62.5,87.5,112.5,137.5,162.5,187.5,212.5,237.5,262.5,287.5,312.5,337.5,362.5,387.5,412.5,437.5,462.5,487.5,512.5,537.5,562.5,587.5,612.5,637.5,662.5,687.5,712.5,737.5,762.5,787.5,812.5,837.5,862.5,887.5,912.5,937.5,962.5,987.5])
# Creating weights for histo: y1_MET_0
y1_MET_0_weightsB = numpy.array([0.00959976514098,0.0327868851297,0.0586324026869,0.0731058925189,0.0849209862593,0.0883178257097,0.0855117409463,0.0942253725799,0.0822625901677,0.0692659870533,0.0651307042441,0.0496233937098,0.0367744792671,0.0286516023205,0.021710234748,0.0166888199084,0.0119627838891,0.0129966031145,0.0110766503817,0.00856594296181,0.0082705656183,0.00605523554197,0.0056121695267,0.00354452812213,0.00295377343511,0.00324915077862,0.00354452812213,0.00295377343511,0.00236301874809,0.00191995273282,0.00162457538931,0.00118150952173,0.0013291980458,0.00147688671755,0.000886132178221,0.00103382084998,0.00118150937404,0.000886132030532,0.00118150952173,0.000738443358777])


# Creating data sequence: middle of each bin
xDataC = numpy.array([12.5,37.5,62.5,87.5,112.5,137.5,162.5,187.5,212.5,237.5,262.5,287.5,312.5,337.5,362.5,387.5,412.5,437.5,462.5,487.5,512.5,537.5,562.5,587.5,612.5,637.5,662.5,687.5,712.5,737.5,762.5,787.5,812.5,837.5,862.5,887.5,912.5,937.5,962.5,987.5])
# Creating weights for histo: y1_MET_0
y1_MET_0_weight
xDataG = numpy.array([12.5,37.5,62.5,87.5,112.5,137.5,162.5,187.5,212.5,237.5,262.5,287.5,312.5,337.5,362.5,387.5,412.5,437.5,462.5,487.5,512.5,537.5,562.5,587.5,612.5,637.5,662.5,687.5,712.5,737.5,762.5,787.5,812.5,837.5,862.5,887.5,912.5,937.5,962.5,987.5])
# Creating weights for histo: y1_MET_0
y1_MET_0_weightsG = numpy.array([0.0102974838468,0.0338164228058,0.0528858411752,0.0658530415211,0.0797101439122,0.089244853097,0.0962369731658,0.0799643986785,0.0802186534447,0.0689041401695,0.062801922146,0.051360291851,0.0403000333421,0.0293668918529,0.0235189493223,0.0180523765051,0.0167810840198,0.0111873879647,0.0100432249352,0.00889905983307,0.00813628309829,0.00711924745192,0.00622934126135,0.0044495288802,0.0043223994244,0.00355962268962,0.00292397748332,0.00368675214542,0.0033053658507,0.00381388160122,0.00279684802752,0.00190694121514,0.00165268251082,0.000635647071714,0.00165268251082,0.0010170354391,0.000762776527511,0.000762776527511,0.00139842359923,0.000889905983307])




fig   = plt.figure(figsize=(8,6),dpi=80)

plt.hist(x=xDataA, bins=xBinning, weights=y1_MET_0_weightsA,\
             histtype="step", rwidth=1.0,\
             color=None, edgecolor="black", linewidth=1.5, linestyle="solid",\
             bottom=None, cumulative=False, normed=False, align="mid", orientation="vertical",
             label='No Matching (0 partons)')

plt.hist(x=xDataD, bins=xBinning, weights=y1_MET_0_weightsD,\
             histtype="step", rwidth=1.0,\
             color=None, edgecolor="orange", linewidth=1.5, linestyle="--",\
             bottom=None, cumulative=False, normed=False, align="mid", orientation="vertical",
             label='MLM 30')

plt.hist(x=xDataE, bins=xBinning, weights=y1_MET_0_weightsE,\
             histtype="step", rwidth=1.0,\
             color=None, edgecolor="green", linewidth=1.5, linestyle="--",\
             bottom=None, cumulative=False, normed=False, align="mid", orientation="vertical",
             label='MLM 60')

plt.hist(x=xDataF, bins=xBinning, weights=y1_MET_0_weightsF,\
             histtype="step", rwidth=1.0,\
             color=None, edgecolor="red", linewidth=1.5, linestyle="--",\
             bottom=None, cumulative=False, normed=False, align="mid", orientation="vertical",
             label='MLM 120')

plt.hist(x=xDataG, bins=xBinning, weights=y1_MET_0_weightsG,\
             histtype="step", rwidth=1.0,\
             color=None, edgecolor="blue", linewidth=1.5, linestyle="--",\
             bottom=None, cumulative=False, normed=False, align="mid", orientation="vertical",
             label='MLM 200')

    # Axis
plt.rc('text',usetex=False)
plt.xlabel(r"$\slash{E}_{T}$ $(GeV)$ ",\
               fontsize=16,color="black")
plt.ylabel(r"$\mathrm{Events}$ $(\mathrm{scaled}\ \mathrm{to}\ \mathrm{one})$",\
               fontsize=16,color="black")

plt.gca().set_ylim(0.02,0.1)
plt.gca().set_xlim(0.0,400.)
plt.legend()
# plt.yscale('log')
plt.show()

# %%
METcut = 0.
MET30cut = 0.
MET60cut = 0.
MET120cut = 0.
MET200cut = 0.
for i,x in enumerate(xDataD):
    if x > 200.:
        METcut += y1_MET_0_weightsA[i]
        MET30cut += y1_MET_0_weightsD[i]
        MET60cut += y1_MET_0_weightsE[i]
        MET120cut += y1_MET_0_weightsF[i]
        MET200cut += y1_MET_0_weightsG[i]
print(METcut,MET30cut,MET60cut,MET120cut,MET200cut)
# Out:
# 0.48969998230827694 0.501039485360928 0.49971024705087885 0.47976791432310795 0.48245613468548293
