# %%
import numpy as np
from matplotlib import pyplot as plt
from itertools import product

# %% [markdown]
# ## Strong Production

# %% [markdown]
# ### Fig.7

# %%
atlasCurve = np.genfromtxt('../ATLAS_data/HEPData-ins2628398-v1-csv/excl_strong_mgluino_2400_GeV_obs_nominal.csv',delimiter=',',comments='#')

# %%
mN1 = np.append(np.arange(50.,200.,25.),np.arange(200.,1900.,200.))
tau = np.logspace(-3.,1.0,20)
mGluino = [2000.]
pts = np.array(list(product(mN1,mGluino,tau)))
plt.scatter(pts[:,2],pts[:,0])
plt.plot(atlasCurve[:,0],atlasCurve[:,1],linewidth=3,c='gray',linestyle='dashed')
plt.xscale('log')
plt.xlim(1e-3,1e2)
plt.ylim(25.,2000.)
plt.xlabel(r'$\tau$ (ns)')
plt.ylabel(r'$m_{\tilde \chi_1^0}$ (GeV)')
plt.title(r'$N = %i$' %len(pts))
plt.show()

# %%
ptsIni = [("%1.0f" %pt[0],"%1.0f" %pt[1], "%1.3e" %pt[2]) for pt in pts]

# %%
print(str(ptsIni).replace("'", ""))
# Out:
# [(50, 2000, 1.000e-03), (50, 2000, 1.624e-03), (50, 2000, 2.637e-03), (50, 2000, 4.281e-03), (50, 2000, 6.952e-03), (50, 2000, 1.129e-02), (50, 2000, 1.833e-02), (50, 2000, 2.976e-02), (50, 2000, 4.833e-02), (50, 2000, 7.848e-02), (50, 2000, 1.274e-01), (50, 2000, 2.069e-01), (50, 2000, 3.360e-01), (50, 2000, 5.456e-01), (50, 2000, 8.859e-01), (50, 2000, 1.438e+00), (50, 2000, 2.336e+00), (50, 2000, 3.793e+00), (50, 2000, 6.158e+00), (50, 2000, 1.000e+01), (75, 2000, 1.000e-03), (75, 2000, 1.624e-03), (75, 2000, 2.637e-03), (75, 2000, 4.281e-03), (75, 2000, 6.952e-03), (75, 2000, 1.129e-02), (75, 2000, 1.833e-02), (75, 2000, 2.976e-02), (75, 2000, 4.833e-02), (75, 2000, 7.848e-02), (75, 2000, 1.274e-01), (75, 2000, 2.069e-01), (75, 2000, 3.360e-01), (75, 2000, 5.456e-01), (75, 2000, 8.859e-01), (75, 2000, 1.438e+00), (75, 2000, 2.336e+00), (75, 2000, 3.793e+00), (75, 2000, 6.158e+00), (75, 2000, 1.000e+01), (100, 2000, 1.000e-03), (100, 2000, 1.624e-03), (100, 2000, 2.637e-03), (100, 2000, 4.281e-03), (100, 2000, 6.952e-03), (100, 2000, 1.129e-02), (100, 2000, 1.833e-02), (100, 2000, 2.976e-02), (100, 2000, 4.833e-02), (100, 2000, 7.848e-02), (100, 2000, 1.274e-01), (100, 2000, 2.069e-01), (100, 2000, 3.360e-01), (100, 2000, 5.456e-01), (100, 2000, 8.859e-01), (100, 2000, 1.438e+00), (100, 2000, 2.336e+00), (100, 2000, 3.793e+00), (100, 2000, 6.158e+00), (100, 2000, 1.000e+01), (125, 2000, 1.000e-03), (125, 2000, 1.624e-03), (125, 2000, 2.637e-03), (125, 2000, 4.281e-03), (125, 2000, 6.952e-03), (125, 2000, 1.129e-02), (125, 2000, 1.833e-02), (125, 2000, 2.976e-02), (125, 2000, 4.833e-02), (125, 2000, 7.848e-02), (125, 2000, 1.274e-01), (125, 2000, 2.069e-01), (125, 2000, 3.360e-01), (125, 2000, 5.456e-01), (125, 2000, 8.859e-01), (125, 2000, 1.438e+00), (125, 2000, 2.336e+00), (125, 2000, 3.793e+00), (125, 2000, 6.158e+00), (125, 2000, 1.000e+01), (150, 2000, 1.000e-03), (150, 2000, 1.624e-03), (150, 2000, 2.637e-03), (150, 2000, 4.281e-03), (150, 2000, 6.952e-03), (150, 2000, 1.129e-02), (150, 2000, 1.833e-02), (150, 2000, 2.976e-02), (150, 2000, 4.833e-02), (150, 2000, 7.848e-02), (150, 2000, 1.274e-01), (150, 2000, 2.069e-01), (150, 2000, 3.360e-01), (150, 2000, 5.456e-01), (150, 2000, 8.859e-01), (150, 2000, 1.438e+00), (150, 2000, 2.336e+00), (150, 2000, 3.793e+00), (150, 2000, 6.158e+00), (150, 2000, 1.000e+01), (175, 2000, 1.000e-03), (175, 2000, 1.624e-03), (175, 2000, 2.637e-03), (175, 2000, 4.281e-03), (175, 2000, 6.952e-03), (175, 2000, 1.129e-02), (175, 2000, 1.833e-02), (175, 2000, 2.976e-02), (175, 2000, 4.833e-02), (175, 2000, 7.848e-02), (175, 2000, 1.274e-01), (175, 2000, 2.069e-01), (175, 2000, 3.360e-01), (175, 2000, 5.456e-01), (175, 2000, 8.859e-01), (175, 2000, 1.438e+00), (175, 2000, 2.336e+00), (175, 2000, 3.793e+00), (175, 2000, 6.158e+00), (175, 2000, 1.000e+01), (200, 2000, 1.000e-03), (200, 2000, 1.624e-03), (200, 2000, 2.637e-03), (200, 2000, 4.281e-03), (200, 2000, 6.952e-03), (200, 2000, 1.129e-02), (200, 2000, 1.833e-02), (200, 2000, 2.976e-02), (200, 2000, 4.833e-02), (200, 2000, 7.848e-02), (200, 2000, 1.274e-01), (200, 2000, 2.069e-01), (200, 2000, 3.360e-01), (200, 2000, 5.456e-01), (200, 2000, 8.859e-01), (200, 2000, 1.438e+00), (200, 2000, 2.336e+00), (200, 2000, 3.793e+00), (200, 2000, 6.158e+00), (200, 2000, 1.000e+01), (400, 2000, 1.000e-03), (400, 2000, 1.624e-03), (400, 2000, 2.637e-03), (400, 2000, 4.281e-03), (400, 2000, 6.952e-03), (400, 2000, 1.129e-02), (400, 2000, 1.833e-02), (400, 2000, 2.976e-02), (400, 2000, 4.833e-02), (400, 2000, 7.848e-02), (400, 2000, 1.274e-01), (400, 2000, 2.069e-01), (400, 2000, 3.360e-01), (400, 2000, 5.456e-01), (400, 2000, 8.859e-01), (400, 2000, 1.438e+00), (400, 2000, 2.336e+00), (400, 2000, 3.793e+00), (400, 2000, 6.158e+00), (400, 2000, 1.000e+01), (600, 2000, 1.000e-03), (600, 2000, 1.624e-03), (600, 2000, 2.637e-03), (600, 2000, 4.281e-03), (600, 2000, 6.952e-03), (600, 2000, 1.129e-02), (600, 2000, 1.833e-02), (600, 2000, 2.976e-02), (600, 2 ...
