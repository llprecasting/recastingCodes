# %%
import sys,os,glob,copy
sys.path.append('../')
import numpy as np
from numpy.linalg import norm
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from scipy.interpolate import LinearNDInterpolator,interp2d
import matplotlib as mpl
from matplotlib.colors import LogNorm
from IPython.display import display, Markdown
import glob
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"]})

plt.rcParams.update({"savefig.dpi" : 300}) #Figure resolution


#Define plotting style:
sns.set() #Set style
sns.set_style('ticks',{'font.family':'Times New Roman', 'font.serif':'Times New Roman'})
sns.set_context('paper', font_scale=1.8)
cm = plt.cm.get_cmap('RdYlBu')


pd.set_option('display.max_rows', 200)

# %%
atlasData = pd.read_pickle('../ATLAS_data/CutFlow_Stau.pcl')
atlasData['label'] = 'ATLAS'

# %%
files = {'10 ns' : '../Stau_0j_match/Events/run_19/stau_400_10.00ns_atlas_2018_42.pcl'}

# %%
allData = atlasData
for label,f in files.items():
    recastData = pd.read_pickle(f)
    recastData['label'] = label
    columns = [c for c in atlasData.columns if c in recastData]
    recastData = recastData[columns]
    allData = pd.concat((allData,recastData))
    
allData.sort_values(['mLLP','tau_ns'],inplace=True)

# %%
allData.T
# Out:
#                                                                0  \
# mLLP                                                       400.0
# tau_ns                                                      10.0
# Total                                               (198.3, 1.0)
# Event and jet Cleaning                                       NaN
# Trigger                                          (99.02, 0.4994)
# Primary vertex                                               NaN
# $E_{T}^{miss}>170$ GeV                           (63.99, 0.3227)
# Track in PV                                                  NaN
# $p_{T} > 50$ GeV                                  (59.3, 0.2991)
# Track quality requirements                                   NaN
# Track isolation                                   (59.3, 0.2991)
# $p_{T} > 120$ GeV                                (58.64, 0.2957)
# Track momentum uncertainty                                   NaN
# $|\eta|<1.8$                                     (56.53, 0.2851)
# $m_{T}({track},{p}_{{T}}^{{ miss}}) > 130$ GeV   (56.53, 0.2851)
# Electron veto                                                NaN
# Hadron/tau veto                                              NaN
# (SR-Low - no mass Window)                       (5.479, 0.02763)
# (SR-High - no mass Window)                      (4.361, 0.02199)
# label                                                      10 ns
#
#                                                                1  \
# mLLP                                                       400.0
# tau_ns                                                      10.0
# Total                                               (198.3, 1.0)
# Event and jet Cleaning                                       NaN
# Trigger                                          (99.02, 0.4994)
# Primary vertex                                               NaN
# $E_{T}^{miss}>170$ GeV                           (63.99, 0.3227)
# Track in PV                                                  NaN
# $p_{T} > 50$ GeV                                  (59.3, 0.2991)
# Track quality requirements                                   NaN
# Track isolation                                   (59.3, 0.2991)
# $p_{T} > 120$ GeV                                (58.64, 0.2957)
# Track momentum uncertainty                                   NaN
# $|\eta|<1.8$                                     (56.53, 0.2851)
# $m_{T}({track},{p}_{{T}}^{{ miss}}) > 130$ GeV   (56.53, 0.2851)
# Electron veto                                                NaN
# Hadron/tau veto                                              NaN
# (SR-Low - no mass Window)                       (5.479, 0.02763)
# (SR-High - no mass Window)                      (4.361, 0.02199)
# label                                                      10 ns
#
#                                                              0
# mLLP                                                     400.0
# tau_ns                                                    10.0
# Total                                             (258.0, 1.0)
# Event and jet Cleaning                          (256.0, 0.991)
# Trigger                                         (129.0, 0.499)
# Primary vertex                                  (129.0, 0.499)
# $E_{T}^{miss}>170$ GeV                           (87.0, 0.337)
# Track in PV                                      (84.9, 0.328)
# $p_{T} > 50$ GeV                                 (83.7, 0.324)
# Track quality requirements                       (80.4, 0.311)
# Track isolation                                  (79.4, 0.307)
# $p_{T} > 120$ GeV                                (78.9, 0.305)
# Track momentum uncertainty                       (78.3, 0.303)
# $|\eta|<1.8$                                     (73.3, 0.284)
# $m_{T}({track},{p}_{{T}}^{{ miss}}) > 130$ GeV   (60.6, 0.234)
# Electron veto                                    (60.0, 0.232)
# Hadron/tau veto                                  (58.8, 0.228)
# (SR-Low - no mass Window)                        (6.79, 0.026)
# (SR-High - no mass Window)                       (6.18, 0.024)
# label                                                    ATLAS

# %%
recastData = pd.read_pickle(f)
recastData.T
# Out:
#                                                                0  \
# Luminosity (1/fb)                                          139.0
# Regime                                             Long Lifetime
# SR                                              SR-Inclusive_Low
# Target Mass [GeV]                                          400.0
# $N_s$                                                   3.339829
# $\sigma_{Ns}$                                           0.058024
# mLLP                                                       400.0
# mLSP                                                         0.0
# width                                                        0.0
# tau_ns                                                      10.0
# Total MC Events                                            27886
# Total xsec-pTcut (pb)                                   0.001426
# Total xsec (pb)                                         0.001426
# Total                                               (198.3, 1.0)
# Trigger                                          (99.02, 0.4994)
# $E_{T}^{miss}>170$ GeV                           (63.99, 0.3227)
# $p_{T} > 50$ GeV                                  (59.3, 0.2991)
# Track isolation                                   (59.3, 0.2991)
# $p_{T} > 120$ GeV                                (58.64, 0.2957)
# $|\eta|<1.8$                                     (56.53, 0.2851)
# $m_{T}({track},{p}_{{T}}^{{ miss}}) > 130$ GeV   (56.53, 0.2851)
# (Acceptance)                                     (166.6, 0.8405)
# (SR-Low - no mass Window)                       (5.479, 0.02763)
# (SR-High - no mass Window)                      (4.361, 0.02199)
#
#                                                                 1
# Luminosity (1/fb)                                           139.0
# Regime                                              Long Lifetime
# SR                                              SR-Inclusive_High
# Target Mass [GeV]                                           400.0
# $N_s$                                                    3.189531
# $\sigma_{Ns}$                                            0.082091
# mLLP                                                        400.0
# mLSP                                                          0.0
# width                                                         0.0
# tau_ns                                                       10.0
# Total MC Events                                             27886
# Total xsec-pTcut (pb)                                    0.001426
# Total xsec (pb)                                          0.001426
# Total                                                (198.3, 1.0)
# Trigger                                           (99.02, 0.4994)
# $E_{T}^{miss}>170$ GeV                            (63.99, 0.3227)
# $p_{T} > 50$ GeV                                   (59.3, 0.2991)
# Track isolation                                    (59.3, 0.2991)
# $p_{T} > 120$ GeV                                 (58.64, 0.2957)
# $|\eta|<1.8$                                      (56.53, 0.2851)
# $m_{T}({track},{p}_{{T}}^{{ miss}}) > 130$ GeV    (56.53, 0.2851)
# (Acceptance)                                      (166.6, 0.8405)
# (SR-Low - no mass Window)                        (5.479, 0.02763)
# (SR-High - no mass Window)                       (4.361, 0.02199)
